# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup

# %%
html = urlopen('https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSkwyMHZNREZ4ZVdkc0VnVmxiaTFWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen')

bsobj=BeautifulSoup(html.read(), 'lxml')

# %%
print(bsobj)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><base href="https://news.google.com/"/><meta content="origin" name="referrer"/><link href="https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSkwyMHZNREZ4ZVdkc0VnVmxiaTFWVXlnQVAB" rel="canonical"/><meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/><link href="https://lh3.googleusercontent.com/J6_coFbogxhRI9iM864NL_liGXvsQp2AupsKei7z0cNNfDvGUmWUy20nuUhkREQyrpY4bEeIBuc=w16" rel="shortcut icon" sizes="16x16"/><link href="https://lh3.googleusercontent.com/J6_coFbogxhRI9iM864NL_liGXvsQp2AupsKei7z0cNNfDvGUmWUy20nuUhkREQyrpY4bEeIBuc=w24" rel="shortcut icon" sizes="24x24"/><link href="https://lh3.googleusercontent.com/J6_coFbogxhRI9iM864NL_liGXvsQp2AupsKei7z0cNNfDvGUmWUy20nuUhkREQyrpY4bEeIBuc=w32" rel="shortcut icon" sizes="32x32"/><link href="https://lh3.googleusercontent.com/J6_coFbogxhRI9iM864NL_liGXvsQp2AupsKei7z0cNNfDvGUmWUy20nuUhkREQyrpY4bEeIBuc=w48" rel="shortcut icon" sizes="48x48"/><script data-id="_gd" nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">window.WIZ_global_data = {"DpimGf":false,"EP1ykd":["/_/*","/accounts/*","/subscribewithgoogleclientui/*","/swg/*","/swglib/*"],"FdrFJe":"6292924236378123659","Fwhl2e":"%.@.[\"en-US\",\"US\",[\"WEB_TEST_1_0_0\"]\n,null,null,2,null,\"US:en\",[\"Python-urllib/3.6,gzip(gfe)\",\"https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSkwyMHZNREZ4ZVdkc0VnVmxiaTFWVXlnQVAB?hl\\u003den-US\\u0026gl\\u003dUS\\u0026ceid\\u003dUS:en\",\"GET\",\"GET /topics/CAAqJggKIiBDQkFTRWdvSkwyMHZNREZ4ZVdkc0VnVmxiaTFWVXlnQVAB?hl\\u003den-US\\u0026gl\\u003dUS\\u0026ceid\\u003dUS%3Aen HTTP/1.1\\r\\nHost: news.google.com\\r\\nX-Google-GFE-Frontline-Info: vip\\u003d172.217.10.14,server_port\\u003d443,client_port\\u003d53467,tcp_connection_request_count\\u003d0,header_order\\u003dEHUN,gfe_version\\u003d2.571.0,ssl,ssl_info\\u003dTLSv1.2:RNA:T,tlsext\\u003dS,sni\\u003dnews.google.com,hex_encoded_client_hello\\-00-0000000b000a0023000d000f0015,c\\u003dc02b,rtt_source\\u003dtcp,rtt\\u003d10,srtt\\u003d11,client_protocol\\u003dHTTP/1.1,client_transport\\u003dtcp,gfe\\u003daclgag5,pzf\\u003dWindows 7 or 8 [4:120+8:0:1460:8192/2:mss/nop/ws/nop/nop/sok:df/id+:0] [tos:0x20],vip_region\\u003ddefault,asn\\u003d701\\r\\nX-Google-GFE-Can-Retry: yes\\r\\nX-GFE-SSL: yes\\r\\nX-Google-GFE-Can-Redirect: true\\r\\nX-User-IP: 108.14.7.243\\r\\nX-Google-Service: dots-splash-server-http-prod\\r\\nX-Google-GFE-Service-Trace: dots-splash-server-http-prod\\r\\nConnection: Keep-Alive\\r\\nAccept-Encoding: identity,gzip(gfe)\\r\\nUser-Agent: Python-urllib/3.6,gzip(gfe)\\r\\nX-Google-Request-UID: [2002:a0c:e0d0::]:4416:aclgag5:80:816924:5771107\\r\\n\\r\\n\"]\n]\n,\"en-US\",\"US\",false,[1,3]\n,1,true,\"198134699\"]\n","Im6cmf":"_/DotsSplashUi","JxkZB":{"Y6pYzf":"1","upfWee":"1","gdtgie":"1","DjbPwf":"1","dXd9Yd":"1","x3Dmtb":"1","jflYXc":"1","Ntv0se":"1","wfA15d":"1","Grzi4e":"1","ZMDTEb":"1","OWrIlb":"1","qYhfLd":"1","WpdNDd":"1","kBCCWb":"1","Gj9KId":"1","YOVgSd":"1","QP37Sc":"1","FZXaob":"1","mHFgtf":"1","oODGhb":"2","Yn1HDc":"2","qI5pHd":"2","lbEaDd":"2","CFi2ve":"2","X5BmUe":"2","Wv28Md":"2","MC03je":"2","j3JEcd":"2","VoNCqb":"2","oq7Doc":"2","xZTw2c":"2","XGKYed":"2","XaDMu":"2","MjosGd":"2","Ap8qnb":"2","wzepRb":"2"},"LVIXXb":1,"LoQv7e":false,"QrtxK":"","S06Grb":"","cfb2h":"boq_dotssplashserver_20180525.07_p0","eNnkwf":"1527815251","eptZe":"/_/DotsSplashUi/","fPDxwd":[],"fuqsbf":{},"gGcLoe":false,"nQyAE":{"AUkF5c":"UA-115545151-2","IrjXhf":"10000","wkakMe":"300","tBSlob":"false"},"qEndFb":"DotsSplashUi","qymVe":"NO2BA7TaWDxP-HZFCmBeg8TAuUs","rtQCxc":240,"w2btAe":"%.@.null,null,\"\",false]\n","zChJod":"%.@.]\n"};</script><script nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">(function(){'use ...
# b.l=function(r){function h(a){var c={};c[a]=g();p.push(c)}function t(a,c){if(!c||"none"==c.style.display)return!1;var d=a.defaultView;if(d&&d.getComputedStyle&&(d=d.getComputedStyle(c),"hidden"==d.visibility||"0px"==d.height||"0px"==d.width))return!1;if(!c.getBoundingClientRect)return!0;var f=c.getBoundingClientRect();c=f.left+b.pageXOffset;d=f.top+b.pageYOffset;if(0>d+f.height||0>c+f.width||0>=f.height||0>=f.width)return!1;a=a.documentElement;return d<=(b.innerHeight||a.clientHeight)&&c<=(b.innerWidth||
# a.clientWidth)}function q(a,c){k[a]=Math.max(k[a]||0,g());l[a]=l[a]||t(b.document,c)}b.cc_aid=r;b.iml_start=n;var p=[{"":n},{n2h:m}];b.cc_latency=p;b.ccTick=h;b.onJsLoad=function(){h("jsl")};b.onCssLoad=function(){h("cssl")};var k={};b.iml_ticks=k;var l={};b.iml_is_visible=l;b._recordIml=q;document.documentElement.addEventListener("load",function(a){a=a.target;if("IMG"==a.tagName&&!a.hasAttribute("data-iid")&&!a.hasAttribute("data-src")&&!a.hasAttribute("data-ils")){var c=a.src;c&&q(c,a)}},!0)};}).call(this);
# l('AAbh7b')</script><script nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">var _F_cssRowKey = 'boq-dots.DotsSplashUi.-19ntymyv3s0eg.L.X.O';var _F_combinedSignature = 'ALs0n2PYYf6XUIf6hrNHd9YazvMMmdy7sA';function _DumpException(e) {if (goog.global['$googDebugFname'] && e && e.message && !e.fileName) {e.message += ' in ' + goog.global['$googDebugFname'];}throw e;}document.createElement('content');</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.-19ntymyv3s0eg.L.X.O/m=collection,_b,_tp/am=oAI/d=1/rs=ALs0n2MXi3j1z_tfc3d1qLIie-lT5sMhtw" nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">html{height:100%;overflow:hidden}body{height:100%;overflow:hidden;color:rgba(0,0,0,0.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}button{outline:none}a{text-decoration:none;color:#2962ff}img{border:none}#apps-debug-tracers{display:none}.MCcOAc{bottom:0;left:0;position:absolute;right:0;top:0;overflow:hidden;z-index:1}.MCcOAc>.pGxpHc{flex-shrink:0;box-flex:0;flex-grow:0}.IqBfM>.HLlAHb{align-items:center;display:-webkit-box;display:-moz-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:60px;position:absolute;right:16px;top:0;z-index:9999}.VUoKZ{display:none;position:absolute;top:0;left:0;right:0;height:3px;z-index:1001}.TRHLAc{position:absolute;top:0;left:0;width:25%;height:100%;background:#68e;transform-origin:0 0}.mIM26c .VUoKZ{display:block}.mIM26c .TRHLAc{animation:boqChromeapiPageProgressAnimation 1s infinite;animation-timing-function:cubic-bezier(0.4,0.0,1,1);animation-delay:.1s}.ghyPEc .VUoKZ{position:fixed}@keyframes boqChromeapiPageProgressAnimation{0%{transform:scaleX(0)}50%{transform:scaleX(5)}to{transform:scaleX(5) translateX(100%)}}@keyframes primary-indeterminate-translate{0%{transform:translateX(-145.166611%)}20%{animation-timing-function:cubic-bezier(.5,0,.701732,.495819);transform:translateX(-145.166611%)}59.15%{animation-timing-function:cubic-bezier(.302435,.381352,.55,.956352);transform:translateX(-61.495191%)}to{transform:translateX(55.444446%)}}@keyframes primary-indeterminate-translate-reverse{0%{transform:translateX(145.166611%)}20%{animation-timing-function:cubic-bezier(.5,0,.701732,.495819);transform:translateX(145.166611%)}59.15%{animation-timing-function:cubic-bezier(.302435,.381352,.55,.956352);transform:translateX(61.495191%)}to{transform:translateX(-55.4444461%)}}@keyframes primary-indeterminate-scale{0%{transform:scaleX(.08)}36.65%{animation-timing-function:cubic-bezier(.334731,.124820,.785844,1);transform:scaleX(.08)}69.15%{animation-timing-function:cubic-bezier(.06,.11,.6,1);transform:scaleX(.661479)}to{transform:scaleX(.08)}}@keyframes auxiliary-indeterminate-translate{0%{animation-timing-function:cubic-bezier(.15,0,.515058,.409685);transform:translateX(-54.888891%)}25%{animation-timing-function:cubic-bezier(.310330,.284058,.8,.733712);transform:translateX(-17.236978%)}48.35%{animation-timing-function:cubic-bezier(.4,.627035,.6,.902026);transform:translateX(29.497274%)}to{transform:translateX(105.388891%)}}@keyframes auxiliary-indeterminate-translate-reverse{0%{animation-timing-function:cubic-bezier(.15,0,.515058,.409685);transform:translateX(54.888891%)}25%{animation-timing-function:cubic-bezier(.310330,.284058,.8,.733712);transform:translateX(17.236978%)}48.35%{animation-timing-function:cubic-bezier(.4,.627035,.6,.902026);transform:translateX(-29.497274%)}to{transform:translateX(-105.388891%)}}@keyframes auxiliary-indeterminate-scale{0%{animation-timing-function:cubic-bezier(.205028,.057051,.576610,.453971);transform:scaleX(.08)}19.15%{animation-timing-function:cubic-bezier(.152313,.196432,.648374,1.004315);transform:scaleX(.457104)}44.15%{animation-timing-function:cubic-bezier(.257759,.003163,.211762,1.381790);transform:scaleX(.727960)}to{transform:scaleX(.08)}}@keyframes buffering{to{transform:translateX(-10px)}}@keyframes buffering-reverse{to{transform:translateX(10p ...
# /*# sourceURL=/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.-19ntymyv3s0eg.L.X.O/m=collection,_b,_tp/am=oAI/d=1/rs=ALs0n2MXi3j1z_tfc3d1qLIie-lT5sMhtw */</style><script nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">onCssLoad();</script><style nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Material Icons Extended';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/materialiconsextended/v38/kJEjBvgX7BgnkSrUwT8UnLVc38YydejYY-oE_LvM.ttf)format('truetype');}.material-icons-extended{font-family:'Material Icons Extended';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Google Sans Display';font-style:normal;font-weight:400;src:local('Google Sans Display Regular'),local('GoogleSansDisplay-Regular'),url(//fonts.gstatic.com/s/googlesansdisplay/v5/ea8FacM9Wef3EJPWRrHjgE4B6CnlZxHVDv79pA.ttf)format('truetype');}@font-face{font-family:'Google Sans Display';font-style:normal;font-weight:500;src:local('Google Sans Display Medium'),local('GoogleSansDisplay-Medium'),url(//fonts.gstatic.com/s/googlesansdisplay/v5/ea8IacM9Wef3EJPWRrHjgE4B6CnlZxHVBg3etBD7SQ.ttf)format('truetype');}@font-face{font-family:'Google Sans Display';font-style:normal;font-weight:700;src:local('Google Sans Display Bold'),local('GoogleSansDisplay-Bold'),url(//fonts.gstatic.com/s/googlesansdisplay/v5/ea8IacM9Wef3EJPWRrHjgE4B6CnlZxHVBkXYtBD7SQ.ttf)format('truetype');}</style><script nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">(function(){'use strict';var e=this;function aa(){}
# function ba(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";
# else if("function"==b&&"undefined"==typeof a.call)return"object";return b}var g=Date.now||function(){return+new Date};var t={};function ca(a,b){if(null===b)return!1;if("contains"in a&&1==b.nodeType)return a.contains(b);if("compareDocumentPosition"in a)return a==b||!!(a.compareDocumentPosition(b)&16);for(;b&&a!=b;)b=b.parentNode;return b==a};function da(a,b){return function(c){c||(c=window.event);return b.call(a,c)}}function u(a){a=a.target||a.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);return a}var v="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),ea="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),ha={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1};
# function x(a){return(a=a.changedTouches&&a.changedTouches[0]||a.touches&&a.touches[0])?{clientX:a.clientX,clientY:a.clientY,screenX:a.screenX,screenY:a.screenY}:null}
# function y(a){var b={};b.originalEventType=a.type;b.type="click";for(var c in a){var d=a[c];"type"==c||"srcElement"==c||"function"==ba(d)||(b[c]=d)}b.timeStamp=g();b.defaultPrevented=!1;b.preventDefault=ia;b._propagationStopped=!1;b.stopPropagation=ja;if(a=x(a))b.clientX=a.clientX,b.clientY=a.clientY,b.screenX=a.screenX,b.screenY=a.screenY;return b}function ka(){this._mouseEventsPrevented=!0}function ia(){this.defaultPrevented=!0}function ja(){this._propagationStopped=!0}
# var z={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,TAB:0,TREE:13,TREEITEM:13};function la(a){return(a.getAttribute("type")||a.tagName).toUpperCase()in ma}function na(a){return(a.getAttribute("type")||a.tagName).toUpperCase()in oa}
# var ma={CHECKBOX:!0,OPTION:!0,RADIO:!0},oa={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},pa={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,INPUT:!0,LINK:!0,MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};function qa(){this.j=[];this.a=[];this.c=[];this.i={};this.b=null;this.g=[];this.m=aa}var B,ra,sa="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),ta=String.prototype.trim?function(a){return a.trim()}:function(a){return a.replace(/^\s+/,"").replace(/\s+$/,"")},ua=/\s*;\s*/,C=null;
# function va(a,b){return function(c){var d=b;if("click"==d&&(v&&c.metaKey||!v&&c.ctrlKey||2==c.which||null==c.which&&4==c.button||"auxclick"==c.type||c.shiftKey))d="clickmod";else{var f=c.which||c.keyCode||c.key;ea&&3==f&&(f=13);if(13!=f&&32!=f)f=!1;else{var h=u(c);var k=(h.getAttribute("role")||h.type||h.tagName).toUpperCase();var m;(m="keydown"!=c.type)||("getAttribute"in h?(m=(h.getAttribute("role")||h.tagName).toUpperCase(),m=!na(h)&&("COMBOBOX"!=m||"INPUT"!=m)&&!h.isContentEditable):m=!1,m=!m);
# (m=m||c.ctrlKey||c.shiftKey||c.altKey||c.metaKey||la(h)&&32==f)||((m=h.tagName in ha)||(m=h.getAttributeNode("tabindex"),m=null!=m&&m.specified),m=!(m&&!h.disabled));m?f=!1:(h="INPUT"!=h.tagName.toUpperCase()||h.type,m=!(k in z)&&13==f,f=(0==z[k]%f||m)&&!!h)}f&&(d="clickkey")}h=c.srcElement||c.target;f=D(d,c,h,"",null);for(k=h;k&&k!=this;k=k.__owner||k.parentNode){var l=k;b:{var w,r=l;var n=d;m=c;var p=r.__jsaction;if(!p)if(p=null,"getAttribute"in r&&(p=r.getAttribute("jsaction")),w=p){p=t[w];if(!p){p=
# {};for(var I=w.split(ua),J=0,Ea=I?I.length:0;J<Ea;J++){var A=I[J];if(A){var K=A.indexOf(":"),fa=-1!=K;p[fa?ta(A.substr(0,K)):"click"]=fa?ta(A.substr(K+1)):A}}t[w]=p}r.__jsaction=p}else p=wa,r.__jsaction=p;"clickkey"==n?n="click":"click"!=n||p.click||(n="clickonly");w=null;if(p.click){r=xa(r,m,p);if(!r){n={f:n,action:"",event:null,l:!0};break b}r!=m&&(w=r,n=r.type)}n={f:n,action:p[n]||"",event:w,l:!1}}if(n.l||n.action)break}n&&(f=D(n.f,n.event||c,h,n.action||"",l,f.timeStamp));f&&"touchend"==f.eventType&&
# (f.event._preventMouseEvents=ka);if(n&&n.action){if(k="clickkey"==d)k=u(c),k=(k.type||k.tagName).toUpperCase(),(k=32==(c.which||c.keyCode||c.key)&&"CHECKBOX"!=k)||(k=u(c),h=(k.getAttribute("role")||k.tagName).toUpperCase(),k=k.tagName.toUpperCase()in pa&&"A"!=h&&!la(k)&&!na(k)||"BUTTON"==h);k&&(c.preventDefault?c.preventDefault():c.returnValue=!1);if("mouseenter"==d||"mouseleave"==d)if(k=c.relatedTarget,!("mouseover"==c.type&&"mouseenter"==d||"mouseout"==c.type&&"mouseleave"==d)||k&&(k===l||ca(l,
# k)))f.action="",f.actionElement=null;else{d={};for(var q in c)"function"!==typeof c[q]&&"srcElement"!==q&&"target"!==q&&(d[q]=c[q]);d.type="mouseover"==c.type?"mouseenter":"mouseleave";d.target=d.srcElement=l;d.bubbles=!1;f.event=d;f.targetElement=l}}else f.action="",f.actionElement=null;l=f;a.b&&(q=D(l.eventType,l.event,l.targetElement,l.action,l.actionElement,l.timeStamp),"clickonly"==q.eventType&&(q.eventType="click"),a.b(q,!0));if(l.actionElement){"A"!=l.actionElement.tagName||"click"!=l.eventType&&
# "clickmod"!=l.eventType||null==a.b||(c.preventDefault?c.preventDefault():c.returnValue=!1);if(a.b)a.b(l);else{a.m(l);if((q=e.document)&&!q.createEvent&&q.createEventObject)try{var L=q.createEventObject(c)}catch(Ka){L=c}else L=c;l.event=L;a.g.push(l)}"touchend"==l.event.type&&l.event._mouseEventsPrevented&&(C=y(l.event))}}}function D(a,b,c,d,f,h){return{eventType:a,event:b,targetElement:c,action:d,actionElement:f,timeStamp:h||g()}}var wa={};
# function xa(a,b,c){if("click"==b.type||b.targetTouches&&1<b.targetTouches.length)return b;var d=B,f=b.target;if(f&&ya(f))return b;f=x(b);if("touchstart"!=b.type||c.touchstart||c.touchend)if("touchend"==b.type&&d&&d.node==a)if(b.defaultPrevented||f&&4<Math.abs(f.clientX-d.x)+Math.abs(f.clientY-d.y))B=null;else{C=a=y(b);b.stopPropagation();b.preventDefault();document.createEvent?(b=document.createEvent("MouseEvent"),b.initMouseEvent(a.type,!0,!0,window,a.detail||1,a.screenX||0,a.screenY||0,a.clientX||
# 0,a.clientY||0,a.ctrlKey||!1,a.altKey||!1,a.shiftKey||!1,a.metaKey||!1,a.button||0,a.relatedTarget||null)):(b=document.createEventObject(),b.type=a.type,b.clientX=a.clientX,b.clientY=a.clientY,b.button=a.button,b.detail=a.detail,b.ctrlKey=a.ctrlKey,b.altKey=a.altKey,b.shiftKey=a.shiftKey,b.metaKey=a.metaKey);b.o=a.timeStamp;b._fastclick=!0;a.target.dispatchEvent(b);if(!b.defaultPrevented){if(document.activeElement&&document.activeElement!=b.target&&ya(document.activeElement))try{document.activeElement.blur()}catch(h){}try{window.getSelection().removeAllRanges()}catch(h){}}return null}else"touchmove"==
# b.type&&d&&f&&4<Math.abs(f.clientX-d.x)+Math.abs(f.clientY-d.y)&&(B=null);else return B={node:a,x:f?f.clientX:0,y:f?f.clientY:0},C=null,clearTimeout(ra),ra=setTimeout(za,400),null;return b}function ya(a){a=a.tagName||"";return"TEXTAREA"==a||"INPUT"==a||"SELECT"==a||"OPTION"==a}function za(){B=null}
# function E(a){if(!a._fastclick){var b=C;if(b)if(800<g()-b.timeStamp)C=null;else{var c=4>=Math.abs(a.clientX-b.clientX)+Math.abs(a.clientY-b.clientY);b.target==a.target||c?(a.stopPropagation(),a.preventDefault(),"click"==a.type&&(C=null)):C=null}}}
# function Aa(a,b){return function(c){var d=a,f=b,h=!1;"mouseenter"==d?d="mouseover":"mouseleave"==d&&(d="mouseout");if(c.addEventListener){if("focus"==d||"blur"==d||"error"==d||"load"==d)h=!0;c.addEventListener(d,f,h)}else c.attachEvent&&("focus"==d?d="focusin":"blur"==d&&(d="focusout"),f=da(c,f),c.attachEvent("on"+d,f));return{f:d,h:f,capture:h}}}
# function F(a,b,c){if(!a.i.hasOwnProperty(b)){var d=va(a,b);c=Aa(c||b,d);a.i[b]=d;a.j.push(c);for(d=0;d<a.a.length;++d){var f=a.a[d];f.b.push(c.call(null,f.a))}"click"==b&&F(a,"keydown");"click"==b&&(F(a,"touchstart"),F(a,"touchend"),F(a,"touchmove"),document.addEventListener&&(document.addEventListener("click",E,!0),document.addEventListener("mouseup",E,!0),document.addEventListener("mousedown",E,!0)))}}qa.prototype.h=function(a){return this.i[a]};
# function Ba(a){var b=G,c=a.a;sa&&(c.style.cursor="pointer");for(c=0;c<b.j.length;++c)a.b.push(b.j[c].call(null,a.a))}function Ca(){for(var a=H,b=Da,c=0;c<b.length;++c)if(b[c].a!=a.a&&Fa(b[c].a,a.a))return!0;return!1}function Fa(a,b){for(;a!=b&&b.parentNode;)b=b.parentNode;return a==b};var G=new qa,Ga=window.document.documentElement,M=new function(a){this.a=a;this.b=[]}(Ga),N;a:{for(var O=0;O<G.a.length;O++)if(Fa(G.a[O].a,Ga)){N=!0;break a}N=!1}
# if(N)G.c.push(M);else{Ba(M);G.a.push(M);for(var Da=G.c.concat(G.a),P=[],Q=[],R=0;R<G.a.length;++R){var H=G.a[R];if(Ca()){P.push(H);for(var S=H,T=0;T<S.b.length;++T){var U=S.a,V=S.b[T];U.removeEventListener?U.removeEventListener(V.f,V.h,V.capture):U.detachEvent&&U.detachEvent("on"+V.f,V.h)}S.b=[]}else Q.push(H)}for(R=0;R<G.c.length;++R)H=G.c[R],Ca()?P.push(H):(Q.push(H),Ba(H));G.a=Q;G.c=P}F(G,"click");F(G,"dblclick");F(G,"focus");F(G,"focusin");F(G,"blur");F(G,"error");F(G,"focusout");F(G,"keydown");
# F(G,"keyup");F(G,"keypress");F(G,"load");F(G,"mouseover");F(G,"mouseout");F(G,"mouseenter");F(G,"mouseleave");F(G,"submit");F(G,"touchstart");F(G,"touchend");F(G,"touchmove");F(G,"auxclick");F(G,"change");F(G,"input");F(G,"textinput");F(G,"cut");F(G,"paste");F(G,"mousedown");F(G,"mouseup");F(G,"wheel");F(G,"contextmenu");F(G,"dragover");F(G,"dragenter");F(G,"dragleave");F(G,"drop");F(G,"dragstart");F(G,"dragend");var Ha,Ia;"onwebkitanimationend"in window&&(Ha="webkitAnimationEnd");
# F(G,"animationend",Ha);"onwebkittransitionend"in window&&(Ia="webkitTransitionEnd");F(G,"transitionend",Ia);var Ja=function(a){return{trigger:function(b){var c=a.h(b.type);c||(F(a,b.type),c=a.h(b.type));var d=b.target||b.srcElement;c&&c.call(d.ownerDocument.documentElement,b)},bind:function(b){a.b=b;a.g&&(0<a.g.length&&b(a.g),a.g=null)}}}(G),W=["BOQ_wizbind"],X=window||e;W[0]in X||"undefined"==typeof X.execScript||X.execScript("var "+W[0]);
# for(var Y;W.length&&(Y=W.shift());){var Z;if(Z=!W.length)Z=void 0!==Ja;Z?X[Y]=Ja:X[Y]&&X[Y]!==Object.prototype[Y]?X=X[Y]:X=X[Y]={}};}).call(this);
# </script><script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi.en_US.1Pwdjs50MTw.O/m=_b,_tp/am=oAI/rt=j/d=1/excm=collection,_b,_tp/ed=1/rs=ALs0n2OEp4PR3CVY303WCStCahMaz3u5zg" id="base-js" nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">/* _GlobalPrefix_ */
# "use strict";this.dots_DotsSplashUi=this.dots_DotsSplashUi||{};(function(_){var window=this;
# /* _Module_:_b */
# try{
# var ea,fa,ka,na,sa,aa,ta,wa,xa,za,ya,Aa,Ca,Ha,Ia,Ja;_.ba=function(a){return function(){return aa[a].apply(this,arguments)}};_.ca=function(a,b){return aa[a]=b};ea=function(a){var b=a.dC;_.da(a)&&(b=a.Bb?!a.Bb.fatal:void 0);return b};fa=function(a){var b=a.kj;_.da(a)&&(b=a.Bb?a.Bb.kj:void 0);return b};ka=function(a,b){var c=fa(a);return-1<c?ha([b,_.ia(c,new _.ja(function(b){b(null);a.Bb.Nu=!0}))]):b};na=function(a,b){return ea(a)?_.la(b,function(){return _.ma(null)}):b};
# sa=function(a,b){return _.da(a)&&a.Bb&&a.Bb.zx?b.then(function(b){return!b&&a.Bb&&a.Bb.Nu?(b=new _.oa,_.qa(b,1,2,0),b):null},function(a){return"undefined"!=typeof _.ra&&a instanceof _.ra?a.status:null}):b};aa=[];ta="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){a!=Array.prototype&&a!=Object.prototype&&(a[b]=c.value)};_.va="undefined"!=typeof window&&window===this?this:"undefined"!=typeof window.global&&null!=window.global?window.global:this;
# wa=function(){wa=function(){};_.va.Symbol||(_.va.Symbol=xa)};xa=function(){var a=0;return function(b){return"jscomp_symbol_"+(b||"")+a++}}();za=function(){wa();var a=_.va.Symbol.iterator;a||(a=_.va.Symbol.iterator=_.va.Symbol("iterator"));"function"!=typeof Array.prototype[a]&&ta(Array.prototype,a,{configurable:!0,writable:!0,value:function(){return ya(this)}});za=function(){}};ya=function(a){var b=0;return Aa(function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}})};
# Aa=function(a){za();a={next:a};a[_.va.Symbol.iterator]=function(){return this};return a};_.Ba=function(a){za();var b=a[window.Symbol.iterator];return b?b.call(a):ya(a)};Ca=function(a,b){if(b){var c=_.va;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];e in c||(c[e]={});c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&null!=b&&ta(c,a,{configurable:!0,writable:!0,value:b})}};
# Ca("Promise",function(a){function b(){this.b=null}function c(a){return a instanceof e?a:new e(function(b){b(a)})}if(a)return a;b.prototype.g=function(a){null==this.b&&(this.b=[],this.j());this.b.push(a)};b.prototype.j=function(){var a=this;this.i(function(){a.o()})};var d=_.va.setTimeout;b.prototype.i=function(a){d(a,0)};b.prototype.o=function(){for(;this.b&&this.b.length;){var a=this.b;this.b=[];for(var b=0;b<a.length;++b){var c=a[b];a[b]=null;try{c()}catch(r){this.s(r)}}}this.b=null};b.prototype.s=
# function(a){this.i(function(){throw a;})};var e=function(a){this.g=0;this.i=void 0;this.b=[];var b=this.s();try{a(b.resolve,b.reject)}catch(m){b.reject(m)}};e.prototype.s=function(){function a(a){return function(d){c||(c=!0,a.call(b,d))}}var b=this,c=!1;return{resolve:a(this.ka),reject:a(this.j)}};e.prototype.ka=function(a){if(a===this)this.j(new TypeError("A Promise cannot resolve to itself"));else if(a instanceof e)this.S(a);else{a:switch(typeof a){case "object":var b=null!=a;break a;case "function":b=
# !0;break a;default:b=!1}b?this.H(a):this.o(a)}};e.prototype.H=function(a){var b=void 0;try{b=a.then}catch(m){this.j(m);return}"function"==typeof b?this.T(b,a):this.o(a)};e.prototype.j=function(a){this.u(2,a)};e.prototype.o=function(a){this.u(1,a)};e.prototype.u=function(a,b){if(0!=this.g)throw Error("a`"+a+"`"+b+"`"+this.g);this.g=a;this.i=b;this.w()};e.prototype.w=function(){if(null!=this.b){for(var a=0;a<this.b.length;++a)f.g(this.b[a]);this.b=null}};var f=new b;e.prototype.S=function(a){var b=
# this.s();a.hj(b.resolve,b.reject)};e.prototype.T=function(a,b){var c=this.s();try{a.call(b,c.resolve,c.reject)}catch(r){c.reject(r)}};e.prototype.then=function(a,b){function c(a,b){return"function"==typeof a?function(b){try{d(a(b))}catch(C){f(C)}}:b}var d,f,h=new e(function(a,b){d=a;f=b});this.hj(c(a,d),c(b,f));return h};e.prototype["catch"]=function(a){return this.then(void 0,a)};e.prototype.hj=function(a,b){function c(){switch(d.g){case 1:a(d.i);break;case 2:b(d.i);break;default:throw Error("b`"+
# d.g);}}var d=this;null==this.b?f.g(c):this.b.push(c)};e.resolve=c;e.reject=function(a){return new e(function(b,c){c(a)})};e.race=function(a){return new e(function(b,d){for(var e=_.Ba(a),f=e.next();!f.done;f=e.next())c(f.value).hj(b,d)})};e.all=function(a){var b=_.Ba(a),d=b.next();return d.done?c([]):new e(function(a,e){function f(b){return function(c){h[b]=c;k--;0==k&&a(h)}}var h=[],k=0;do h.push(void 0),k++,c(d.value).hj(f(h.length-1),e),d=b.next();while(!d.done)})};return e});var Da;
# if("function"==typeof Object.setPrototypeOf)Da=Object.setPrototypeOf;else{var Ea;a:{var Fa={a:!0},Ga={};try{Ga.__proto__=Fa;Ea=Ga.a;break a}catch(a){}Ea=!1}Da=Ea?function(a,b){a.__proto__=b;if(a.__proto__!==b)throw new TypeError(a+" is not extensible");return a}:null}Ha=Da;Ia="function"==typeof Object.create?Object.create:function(a){var b=function(){};b.prototype=a;return new b};
# _.l=function(a,b){a.prototype=Ia(b.prototype);a.prototype.constructor=a;if(Ha)Ha(a,b);else for(var c in b)if("prototype"!=c)if(Object.defineProperties){var d=Object.getOwnPropertyDescriptor(b,c);d&&Object.defineProperty(a,c,d)}else a[c]=b[c];a.$=b.prototype};Ja=function(a,b,c){a instanceof String&&(a=String(a));for(var d=a.length,e=0;e<d;e++){var f=a[e];if(b.call(c,f,e,a))return{wp:e,Uq:f}}return{wp:-1,Uq:void 0}};
# Ca("Array.prototype.findIndex",function(a){return a?a:function(a,c){return Ja(this,a,c).wp}});var Ka=function(a,b,c){if(null==a)throw new TypeError("The 'this' value for String.prototype."+c+" must not be null or undefined");if(b instanceof RegExp)throw new TypeError("First argument to String.prototype."+c+" must not be a regular expression");return a+""};Ca("Array.prototype.find",function(a){return a?a:function(a,c){return Ja(this,a,c).Uq}});
# Ca("String.prototype.endsWith",function(a){return a?a:function(a,c){var b=Ka(this,a,"endsWith");void 0===c&&(c=b.length);c=Math.max(0,Math.min(c|0,b.length));for(var e=a.length;0<e&&0<c;)if(b[--c]!=a[--e])return!1;return 0>=e}});Ca("String.prototype.startsWith",function(a){return a?a:function(a,c){var b=Ka(this,a,"startsWith"),e=b.length,f=a.length;c=Math.max(0,Math.min(c|0,b.length));for(var h=0;h<f&&c<e;)if(b[c++]!=a[h++])return!1;return h>=f}});
# Ca("Object.is",function(a){return a?a:function(a,c){return a===c?0!==a||1/a===1/c:a!==a&&c!==c}});Ca("String.prototype.includes",function(a){return a?a:function(a,c){return-1!==Ka(this,a,"includes").indexOf(a,c||0)}});var La=function(a,b){return Object.prototype.hasOwnProperty.call(a,b)},Ma="function"==typeof Object.assign?Object.assign:function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(d)for(var e in d)La(d,e)&&(a[e]=d[e])}return a};Ca("Object.assign",function(a){return a||Ma});
# Ca("WeakMap",function(a){function b(a){La(a,d)||ta(a,d,{value:{}})}function c(a){var c=Object[a];c&&(Object[a]=function(a){b(a);return c(a)})}if(function(){if(!a||!Object.seal)return!1;try{var b=Object.seal({}),c=Object.seal({}),d=new a([[b,2],[c,3]]);if(2!=d.get(b)||3!=d.get(c))return!1;d["delete"](b);d.set(c,4);return!d.has(b)&&4==d.get(c)}catch(r){return!1}}())return a;var d="$jscomp_hidden_"+Math.random();c("freeze");c("preventExtensions");c("seal");var e=0,f=function(a){this.b=(e+=Math.random()+
# 1).toString();if(a){wa();za();a=_.Ba(a);for(var b;!(b=a.next()).done;)b=b.value,this.set(b[0],b[1])}};f.prototype.set=function(a,c){b(a);if(!La(a,d))throw Error("c`"+a);a[d][this.b]=c;return this};f.prototype.get=function(a){return La(a,d)?a[d][this.b]:void 0};f.prototype.has=function(a){return La(a,d)&&La(a[d],this.b)};f.prototype["delete"]=function(a){return La(a,d)&&La(a[d],this.b)?delete a[d][this.b]:!1};return f});
# Ca("Map",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var b=Object.seal({x:4}),c=new a(_.Ba([[b,"s"]]));if("s"!=c.get(b)||1!=c.size||c.get({x:4})||c.set({x:4},"t")!=c||2!=c.size)return!1;var d=c.entries(),e=d.next();if(e.done||e.value[0]!=b||"s"!=e.value[1])return!1;e=d.next();return e.done||4!=e.value[0].x||"t"!=e.value[1]||!d.next().done?!1:!0}catch(y){return!1}}())return a;wa();za();var b=new window.WeakMap,c=function(a){this.g=
# {};this.b=f();this.size=0;if(a){a=_.Ba(a);for(var b;!(b=a.next()).done;)b=b.value,this.set(b[0],b[1])}};c.prototype.set=function(a,b){a=0===a?0:a;var c=d(this,a);c.list||(c.list=this.g[c.id]=[]);c.md?c.md.value=b:(c.md={next:this.b,Ye:this.b.Ye,head:this.b,key:a,value:b},c.list.push(c.md),this.b.Ye.next=c.md,this.b.Ye=c.md,this.size++);return this};c.prototype["delete"]=function(a){a=d(this,a);return a.md&&a.list?(a.list.splice(a.index,1),a.list.length||delete this.g[a.id],a.md.Ye.next=a.md.next,
# a.md.next.Ye=a.md.Ye,a.md.head=null,this.size--,!0):!1};c.prototype.clear=function(){this.g={};this.b=this.b.Ye=f();this.size=0};c.prototype.has=function(a){return!!d(this,a).md};c.prototype.get=function(a){return(a=d(this,a).md)&&a.value};c.prototype.entries=function(){return e(this,function(a){return[a.key,a.value]})};c.prototype.keys=function(){return e(this,function(a){return a.key})};c.prototype.values=function(){return e(this,function(a){return a.value})};c.prototype.forEach=function(a,b){for(var c=
# this.entries(),d;!(d=c.next()).done;)d=d.value,a.call(b,d[1],d[0],this)};c.prototype[window.Symbol.iterator]=c.prototype.entries;var d=function(a,c){var d=c&&typeof c;"object"==d||"function"==d?b.has(c)?d=b.get(c):(d=""+ ++h,b.set(c,d)):d="p_"+c;var e=a.g[d];if(e&&La(a.g,d))for(a=0;a<e.length;a++){var f=e[a];if(c!==c&&f.key!==f.key||c===f.key)return{id:d,list:e,index:a,md:f}}return{id:d,list:e,index:-1,md:void 0}},e=function(a,b){var c=a.b;return Aa(function(){if(c){for(;c.head!=a.b;)c=c.Ye;for(;c.next!=
# c.head;)return c=c.next,{done:!1,value:b(c)};c=null}return{done:!0,value:void 0}})},f=function(){var a={};return a.Ye=a.next=a.head=a},h=0;return c});
# Ca("Set",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var b=Object.seal({x:4}),d=new a(_.Ba([b]));if(!d.has(b)||1!=d.size||d.add(b)!=d||1!=d.size||d.add({x:4})!=d||2!=d.size)return!1;var e=d.entries(),f=e.next();if(f.done||f.value[0]!=b||f.value[1]!=b)return!1;f=e.next();return f.done||f.value[0]==b||4!=f.value[0].x||f.value[1]!=f.value[0]?!1:e.next().done}catch(h){return!1}}())return a;wa();za();var b=function(a){this.b=
# new window.Map;if(a){a=_.Ba(a);for(var b;!(b=a.next()).done;)this.add(b.value)}this.size=this.b.size};b.prototype.add=function(a){a=0===a?0:a;this.b.set(a,a);this.size=this.b.size;return this};b.prototype["delete"]=function(a){a=this.b["delete"](a);this.size=this.b.size;return a};b.prototype.clear=function(){this.b.clear();this.size=0};b.prototype.has=function(a){return this.b.has(a)};b.prototype.entries=function(){return this.b.entries()};b.prototype.values=function(){return this.b.values()};b.prototype.keys=
# b.prototype.values;b.prototype[window.Symbol.iterator]=b.prototype.values;b.prototype.forEach=function(a,b){var c=this;this.b.forEach(function(d){return a.call(b,d,d,c)})};return b});Ca("Array.from",function(a){return a?a:function(a,c,d){za();c=null!=c?c:function(a){return a};var b=[],f=a[window.Symbol.iterator];if("function"==typeof f)for(a=f.call(a);!(f=a.next()).done;)b.push(c.call(d,f.value));else{f=a.length;for(var h=0;h<f;h++)b.push(c.call(d,a[h]))}return b}});
# Ca("Number.isFinite",function(a){return a?a:function(a){return"number"!==typeof a?!1:!(0,window.isNaN)(a)&&window.Infinity!==a&&-window.Infinity!==a}});Ca("Number.isInteger",function(a){return a?a:function(a){return Number.isFinite(a)?a===Math.floor(a):!1}});_._DumpException=window._DumpException||function(a){throw a;};window._DumpException=_._DumpException;
# var Na,Sa,Ta,db,eb,gb,hb,lb;Na=Na||{};_.n=this;_.Oa=function(a){return void 0!==a};_.Pa=function(a){return"string"==typeof a};_.Qa=function(a){return"number"==typeof a};_.Ra=function(a,b,c){a=a.split(".");c=c||_.n;a[0]in c||"undefined"==typeof c.execScript||c.execScript("var "+a[0]);for(var d;a.length&&(d=a.shift());)!a.length&&_.Oa(b)?c[d]=b:c[d]&&c[d]!==Object.prototype[d]?c=c[d]:c=c[d]={}};Sa=/^[\w+/_-]+[=]{0,2}$/;Ta=null;
# _.Va=function(a){a=a.split(".");for(var b=_.n,c=0;c<a.length;c++)if(b=b[a[c]],null==b)return null;return b};_.Wa=function(){};_.Xa=function(){throw Error("d");};_.Ya=function(a){a.Ol=void 0;a.Ha=function(){return a.Ol?a.Ol:a.Ol=new a}};
# _.Za=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";
# else if("function"==b&&"undefined"==typeof a.call)return"object";return b};_.$a=function(a){return"array"==_.Za(a)};_.ab=function(a){var b=_.Za(a);return"array"==b||"object"==b&&"number"==typeof a.length};_.bb=function(a){return"function"==_.Za(a)};_.cb=function(a){var b=typeof a;return"object"==b&&null!=a||"function"==b};_.fb=function(a){return a[db]||(a[db]=++eb)};db="closure_uid_"+(1E9*Math.random()>>>0);eb=0;gb=function(a,b,c){return a.call.apply(a.bind,arguments)};
# hb=function(a,b,c){if(!a)throw Error();if(2<arguments.length){var d=Array.prototype.slice.call(arguments,2);return function(){var c=Array.prototype.slice.call(arguments);Array.prototype.unshift.apply(c,d);return a.apply(b,c)}}return function(){return a.apply(b,arguments)}};_.p=function(a,b,c){Function.prototype.bind&&-1!=Function.prototype.bind.toString().indexOf("native code")?_.p=gb:_.p=hb;return _.p.apply(null,arguments)};
# _.ib=function(a,b){var c=Array.prototype.slice.call(arguments,1);return function(){var b=c.slice();b.push.apply(b,arguments);return a.apply(this,b)}};_.kb=Date.now||function(){return+new Date};
# _.nb=function(a){if(_.n.execScript)_.n.execScript(a,"JavaScript");else if(_.n.eval){if(null==lb){try{_.n.eval("var _evalTest_ = 1;")}catch(d){}if("undefined"!=typeof _.n._evalTest_){try{delete _.n._evalTest_}catch(d){}lb=!0}else lb=!1}if(lb)_.n.eval(a);else{var b=_.n.document,c=b.createElement("SCRIPT");c.type="text/javascript";c.defer=!1;c.appendChild(b.createTextNode(a));b.head.appendChild(c);b.head.removeChild(c)}}else throw Error("e");};lb=null;
# _.q=function(a,b){function c(){}c.prototype=b.prototype;a.$=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.WA=function(a,c,f){for(var d=Array(arguments.length-2),e=2;e<arguments.length;e++)d[e-2]=arguments[e];return b.prototype[c].apply(a,d)}};
# _.ob=function(a){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ob);else{var b=Error().stack;b&&(this.stack=b)}a&&(this.message=String(a));this.b=!0};_.q(_.ob,Error);_.ob.prototype.name="CustomError";var pb;var Ob;_.qb=function(a){return a[a.length-1]};_.rb=Array.prototype.indexOf?function(a,b){return Array.prototype.indexOf.call(a,b,void 0)}:function(a,b){if(_.Pa(a))return _.Pa(b)&&1==b.length?a.indexOf(b,0):-1;for(var c=0;c<a.length;c++)if(c in a&&a[c]===b)return c;return-1};
# _.sb=Array.prototype.lastIndexOf?function(a,b){return Array.prototype.lastIndexOf.call(a,b,a.length-1)}:function(a,b){var c=a.length-1;0>c&&(c=Math.max(0,a.length+c));if(_.Pa(a))return _.Pa(b)&&1==b.length?a.lastIndexOf(b,c):-1;for(;0<=c;c--)if(c in a&&a[c]===b)return c;return-1};_.t=Array.prototype.forEach?function(a,b,c){Array.prototype.forEach.call(a,b,c)}:function(a,b,c){for(var d=a.length,e=_.Pa(a)?a.split(""):a,f=0;f<d;f++)f in e&&b.call(c,e[f],f,a)};
# _.tb=function(a,b,c){var d=a.length,e=_.Pa(a)?a.split(""):a;for(--d;0<=d;--d)d in e&&b.call(c,e[d],d,a)};_.ub=Array.prototype.filter?function(a,b,c){return Array.prototype.filter.call(a,b,c)}:function(a,b,c){for(var d=a.length,e=[],f=0,h=_.Pa(a)?a.split(""):a,k=0;k<d;k++)if(k in h){var m=h[k];b.call(c,m,k,a)&&(e[f++]=m)}return e};
# _.vb=Array.prototype.map?function(a,b,c){return Array.prototype.map.call(a,b,c)}:function(a,b,c){for(var d=a.length,e=Array(d),f=_.Pa(a)?a.split(""):a,h=0;h<d;h++)h in f&&(e[h]=b.call(c,f[h],h,a));return e};_.wb=Array.prototype.reduce?function(a,b,c){return Array.prototype.reduce.call(a,b,c)}:function(a,b,c){var d=c;(0,_.t)(a,function(c,f){d=b.call(void 0,d,c,f,a)});return d};
# _.xb=Array.prototype.some?function(a,b,c){return Array.prototype.some.call(a,b,c)}:function(a,b,c){for(var d=a.length,e=_.Pa(a)?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return!0;return!1};_.yb=Array.prototype.every?function(a,b,c){return Array.prototype.every.call(a,b,c)}:function(a,b,c){for(var d=a.length,e=_.Pa(a)?a.split(""):a,f=0;f<d;f++)if(f in e&&!b.call(c,e[f],f,a))return!1;return!0};_.Ab=function(a,b){b=_.zb(a,b,void 0);return 0>b?null:_.Pa(a)?a.charAt(b):a[b]};
# _.zb=function(a,b,c){for(var d=a.length,e=_.Pa(a)?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.Bb=function(a,b){return 0<=(0,_.rb)(a,b)};_.Cb=function(a){if(!_.$a(a))for(var b=a.length-1;0<=b;b--)delete a[b];a.length=0};_.Db=function(a,b){_.Bb(a,b)||a.push(b)};_.Fb=function(a,b){b=(0,_.rb)(a,b);var c;(c=0<=b)&&_.Eb(a,b);return c};_.Eb=function(a,b){return 1==Array.prototype.splice.call(a,b,1).length};_.Gb=function(a){return Array.prototype.concat.apply([],arguments)};
# _.Hb=function(a){var b=a.length;if(0<b){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};_.Ib=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ab(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var h=0;h<f;h++)a[e+h]=d[h]}else a.push(d)}};_.Kb=function(a,b,c,d){Array.prototype.splice.apply(a,_.Jb(arguments,1))};_.Jb=function(a,b,c){return 2>=arguments.length?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};
# _.Lb=function(a,b){b=b||a;for(var c={},d=0,e=0;e<a.length;){var f=a[e++];var h=f;h=_.cb(h)?"o"+_.fb(h):(typeof h).charAt(0)+h;Object.prototype.hasOwnProperty.call(c,h)||(c[h]=!0,b[d++]=f)}b.length=d};_.Nb=function(a,b){a.sort(b||_.Mb)};_.Pb=function(a,b,c){if(!_.ab(a)||!_.ab(b)||a.length!=b.length)return!1;var d=a.length;c=c||Ob;for(var e=0;e<d;e++)if(!c(a[e],b[e]))return!1;return!0};_.Mb=function(a,b){return a>b?1:a<b?-1:0};Ob=function(a,b){return a===b};
# var Xb,$b,ac,bc,cc,dc,Wb,hc,kc;_.Qb=function(a,b){return 0==a.lastIndexOf(b,0)};_.Rb=function(a,b){var c=a.length-b.length;return 0<=c&&a.indexOf(b,c)==c};_.Sb=function(a){return/^[\s\xa0]*$/.test(a)};_.Tb=String.prototype.trim?function(a){return a.trim()}:function(a){return/^[\s\xa0]*([\s\S]*?)[\s\xa0]*$/.exec(a)[1]};_.Ub=function(a){return(0,window.encodeURIComponent)(String(a))};_.Vb=function(a){return(0,window.decodeURIComponent)(a.replace(/\+/g," "))};
# _.ec=function(a){if(!Wb.test(a))return a;-1!=a.indexOf("&")&&(a=a.replace(Xb,"&amp;"));-1!=a.indexOf("<")&&(a=a.replace($b,"&lt;"));-1!=a.indexOf(">")&&(a=a.replace(ac,"&gt;"));-1!=a.indexOf('"')&&(a=a.replace(bc,"&quot;"));-1!=a.indexOf("'")&&(a=a.replace(cc,"&#39;"));-1!=a.indexOf("\x00")&&(a=a.replace(dc,"&#0;"));return a};Xb=/&/g;$b=/</g;ac=/>/g;bc=/"/g;cc=/'/g;dc=/\x00/g;Wb=/[\x00&<>"']/;_.fc=function(a){return String(a).replace(/([-()\[\]{}+?*.$\^|,:#<!\\])/g,"\\$1").replace(/\x08/g,"\\x08")};
# _.gc=String.prototype.repeat?function(a,b){return a.repeat(b)}:function(a,b){return Array(b+1).join(a)};
# _.ic=function(a,b){var c=0;a=(0,_.Tb)(String(a)).split(".");b=(0,_.Tb)(String(b)).split(".");for(var d=Math.max(a.length,b.length),e=0;0==c&&e<d;e++){var f=a[e]||"",h=b[e]||"";do{f=/(\d*)(\D*)(.*)/.exec(f)||["","","",""];h=/(\d*)(\D*)(.*)/.exec(h)||["","","",""];if(0==f[0].length&&0==h[0].length)break;c=hc(0==f[1].length?0:(0,window.parseInt)(f[1],10),0==h[1].length?0:(0,window.parseInt)(h[1],10))||hc(0==f[2].length,0==h[2].length)||hc(f[2],h[2]);f=f[3];h=h[3]}while(0==c)}return c};
# hc=function(a,b){return a<b?-1:a>b?1:0};_.jc=function(a){return String(a).replace(/\-([a-z])/g,function(a,c){return c.toUpperCase()})};kc=function(a){return String(a).replace(/([A-Z])/g,"-$1").toLowerCase()};_.mc=function(a){var b=_.Pa(void 0)?_.fc(void 0):"\\s";return a.replace(new RegExp("(^"+(b?"|["+b+"]+":"")+")([a-z])","g"),function(a,b,e){return b+e.toUpperCase()})};
# var sc;a:{var oc=_.n.navigator;if(oc){var qc=oc.userAgent;if(qc){_.nc=qc;break a}}_.nc=""}_.rc=function(a){return-1!=_.nc.indexOf(a)};sc=function(a){for(var b=/(\w[\w ]+)\/([^\s]+)\s*(?:\((.*?)\))?/g,c=[],d;d=b.exec(a);)c.push([d[1],d[2],d[3]||void 0]);return c};
# var Cc;_.tc=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.uc=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.wc=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.xc=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.yc=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.zc=function(a,b){return null!==a&&b in a};_.Ac=function(a){for(var b in a)return!1;return!0};_.Bc=function(a){var b={},c;for(c in a)b[c]=a[c];return b};
# Cc="constructor hasOwnProperty isPrototypeOf propertyIsEnumerable toLocaleString toString valueOf".split(" ");_.Dc=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<Cc.length;f++)c=Cc[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};_.Ec=function(a){var b=arguments.length;if(1==b&&_.$a(arguments[0]))return _.Ec.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};
# var Fc,Gc,Jc,Lc,Mc,Kc;Fc=function(){return _.rc("Trident")||_.rc("MSIE")};Gc=function(){return _.rc("Firefox")};_.Ic=function(){return _.rc("Safari")&&!(_.Hc()||_.rc("Coast")||_.rc("Opera")||_.rc("Edge")||_.rc("Silk")||_.rc("Android"))};_.Hc=function(){return(_.rc("Chrome")||_.rc("CriOS"))&&!_.rc("Edge")};Jc=function(){return _.rc("Android")&&!(_.Hc()||Gc()||_.rc("Opera")||_.rc("Silk"))};
# Lc=function(){function a(a){a=_.Ab(a,d);return c[a]||""}var b=_.nc;if(Fc())return Kc(b);b=sc(b);var c={};(0,_.t)(b,function(a){c[a[0]]=a[1]});var d=_.ib(_.zc,c);return _.rc("Opera")?a(["Version","Opera"]):_.rc("Edge")?a(["Edge"]):_.Hc()?a(["Chrome","CriOS"]):(b=b[2])&&b[1]||""};Mc=function(a){return 0<=_.ic(Lc(),a)};
# Kc=function(a){var b=/rv: *([\d\.]*)/.exec(a);if(b&&b[1])return b[1];b="";var c=/MSIE +([\d\.]+)/.exec(a);if(c&&c[1])if(a=/Trident\/(\d.\d)/.exec(a),"7.0"==c[1])if(a&&a[1])switch(a[1]){case "4.0":b="8.0";break;case "5.0":b="9.0";break;case "6.0":b="10.0";break;case "7.0":b="11.0"}else b="7.0";else b=c[1];return b};
# _.Nc=function(){return _.rc("Android")};_.Oc=function(){return _.rc("iPhone")&&!_.rc("iPod")&&!_.rc("iPad")};_.Pc=function(){return _.Oc()||_.rc("iPad")||_.rc("iPod")};
# _.Qc=function(){var a=_.nc,b="";_.rc("Windows")?(b=/Windows (?:NT|Phone) ([0-9.]+)/,b=(a=b.exec(a))?a[1]:"0.0"):_.Pc()?(b=/(?:iPhone|iPod|iPad|CPU)\s+OS\s+(\S+)/,b=(a=b.exec(a))&&a[1].replace(/_/g,".")):_.rc("Macintosh")?(b=/Mac OS X ([0-9_.]+)/,b=(a=b.exec(a))?a[1].replace(/_/g,"."):"10"):_.Nc()?(b=/Android\s+([^\);]+)(\)|;)/,b=(a=b.exec(a))&&a[1]):_.rc("CrOS")&&(b=/(?:CrOS\s+(?:i686|x86_64)\s+([0-9.]+))/,b=(a=b.exec(a))&&a[1]);return b||""};
# var Uc;_.Rc=function(a){_.Rc[" "](a);return a};_.Rc[" "]=_.Wa;_.Sc=function(a,b){try{return _.Rc(a[b]),!0}catch(c){}return!1};Uc=function(a,b){var c=Tc;return Object.prototype.hasOwnProperty.call(c,a)?c[a]:c[a]=b(a)};var jd,kd,Tc;_.Vc=_.rc("Opera");_.Wc=Fc();_.Xc=_.rc("Edge");_.Yc=_.Xc||_.Wc;_.Zc=_.rc("Gecko")&&!(-1!=_.nc.toLowerCase().indexOf("webkit")&&!_.rc("Edge"))&&!(_.rc("Trident")||_.rc("MSIE"))&&!_.rc("Edge");_.ad=-1!=_.nc.toLowerCase().indexOf("webkit")&&!_.rc("Edge");_.bd=_.rc("Macintosh");_.cd=_.rc("Windows");_.dd=_.Nc();_.ed=_.Oc();_.fd=_.rc("iPad");_.hd=_.rc("iPod");_.id=_.Pc();jd=function(){var a=_.n.document;return a?a.documentMode:void 0};
# a:{var ld="",md=function(){var a=_.nc;if(_.Zc)return/rv:([^\);]+)(\)|;)/.exec(a);if(_.Xc)return/Edge\/([\d\.]+)/.exec(a);if(_.Wc)return/\b(?:MSIE|rv)[: ]([^\);]+)(\)|;)/.exec(a);if(_.ad)return/WebKit\/(\S+)/.exec(a);if(_.Vc)return/(?:Version)[ \/]?(\S+)/.exec(a)}();md&&(ld=md?md[1]:"");if(_.Wc){var nd=jd();if(null!=nd&&nd>(0,window.parseFloat)(ld)){kd=String(nd);break a}}kd=ld}_.od=kd;Tc={};_.pd=function(a){return Uc(a,function(){return 0<=_.ic(_.od,a)})};var rd=_.n.document; _.qd=rd&&_.Wc?jd()||("CSS1Compat"==rd.compatMode?(0,window.parseInt)(_.od,10):5):void 0;
# var sd,td,vd;sd=!_.Wc||9<=Number(_.qd);td=!_.Zc&&!_.Wc||_.Wc&&9<=Number(_.qd)||_.Zc&&_.pd("1.9.1");_.ud=_.Wc&&!_.pd("9");vd=_.Wc||_.Vc||_.ad;var yd;_.zd=function(){this.b="";this.g=yd};_.zd.prototype.ze=!0;_.zd.prototype.qd=function(){return this.b};_.zd.prototype.toString=function(){return"Const{"+this.b+"}"};_.Ad=function(a){return a instanceof _.zd&&a.constructor===_.zd&&a.g===yd?a.b:"type_error:Const"};yd={};_.Bd=function(a){var b=new _.zd;b.b=a;return b};_.Bd("");
# var Cd;_.Dd=function(){this.g="";this.i=Cd};_.Dd.prototype.ze=!0;_.Dd.prototype.qd=function(){return this.g};_.Dd.prototype.Nl=!0;_.Dd.prototype.b=_.ba(2);_.Ed=function(a){if(a instanceof _.Dd&&a.constructor===_.Dd&&a.i===Cd)return a.g;_.Za(a);return"type_error:TrustedResourceUrl"};Cd={};_.Fd=function(a){var b=new _.Dd;b.g=a;return b};
# var Jd,Gd,Kd,Od;_.Hd=function(){this.g="";this.i=Gd};_.Hd.prototype.ze=!0;_.Hd.prototype.qd=function(){return this.g};_.Hd.prototype.Nl=!0;_.Hd.prototype.b=_.ba(1);_.Id=function(a){if(a instanceof _.Hd&&a.constructor===_.Hd&&a.i===Gd)return a.g;_.Za(a);return"type_error:SafeUrl"};Jd=/^(?:(?:https?|mailto|ftp):|[^:/?#]*(?:[/?#]|$))/i;_.Ld=function(a){if(a instanceof _.Hd)return a;a=a.ze?a.qd():String(a);Jd.test(a)||(a="about:invalid#zClosurez");return Kd(a)}; _.Md=function(a){if(a instanceof _.Hd)return a;a=a.ze?a.qd():String(a);Jd.test(a)||(a="about:invalid#zClosurez");return Kd(a)};Gd={};Kd=function(a){var b=new _.Hd;b.g=a;return b};Od=Kd("about:blank");
# ...
# ]
# ,null,[6,[6,"CAAqBggKMMWIAjCATQ"]
# ,"HuffPost",["https://lh3.googleusercontent.com/WzST3mFKeyRXQZDbJJ_1l48s_5ib1c538ELEi5ZTsT8rRuUqAvlX5nAXwcm2msyvtS0bLlEvCyoSENewvDQ"]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,["https://lh3.googleusercontent.com/bG0RhWRdQ-jkYOmOW8WIVwPxJ5nKbW-hhAbvn1wFporMJaqTKZaKfgOMw0YwBZUJwIeZtjK4",null,2400,280,null,"CAUqBggKMMWIAjCS_eGJKmoJaW1hZ2UvcG5n"]
# ,["https://lh3.googleusercontent.com/HGg-I3Y4dmP8B5H_cWzgLBB0Y9-Y-BbWXwRdY-2ACJhm5W0KAa1YWMf7SriQXHOqTKiwkIXaIA",null,3017,383,null,"CAUqBggKMMWIAjCw-L6JKmoJaW1hZ2UvcG5n"]
# ]
# ,null,null,"David Moye",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to HuffPost","publications/CAAqBggKMMWIAjCATQ",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"https://www.huffingtonpost.com/entry/tomi-lahren-tide-pod_us_5a6b607de4b0ddb658c60603",1,"https://m-huffpost-com.cdn.ampproject.org/v/s/m.huffpost.com/us/entry/us_5a6b607de4b0ddb658c60603/amp?ncid\u003dNEWSSTAND0001\u0026amp_js_v\u003d0.1#webview\u003d1",null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEMESoFZ-3qmGCb7mplajfMgqFggEKg0IACoGCAowxYgCMIBNMK2HuAM"]
# ,[3,null,null,[2,[2,"CAIiEHcPf597SstSQVuGWJKEI-AqGAgEKg8IACoHCAowjujJATDXzBUwiJS0AQ"]
# ,"The dangerous teenage Tide Pod challenge may actually boost their sales","By Alessandra Malito The latest, and very idiotic, craze isn’t discouraging people from purchasing the detergent Tide is seeing growing consumer interest, even though their perception of the brand is wavering. Getty Images Teenagers are taking part in a dangerous, and outright stupid, internet challenge, where they ingest Tide Pods, the pocket-size laundry detergent sold by Procter \u0026 Gamble (PG) The craze has consumers questioning the brand. Tide dropped to its lowest consumer perceptive level in nine months after videos began surfacing of teenagers eating the detergent – and yet they’re bu...",[1516826220]
# ,null,"http://www.marketwatch.com/story/the-dangerous-teenage-tide-pod-challenge-may-actually-boost-their-sales-2018-01-24","https://news.google.com/s/CBIw5MnWvDM?oc\u003d3",[["https://lh3.googleusercontent.com/lpJRAKFgKmVQq4Wl2XFpcPqFdZmlEJhHfXDPFYpTMcn-PQrZN350Kaut40Xu9U-2lwJLraMT6sQfZKE0iKU","Tide is seeing growing consumer interest, even though their perception of the brand is wavering.",890,501,"","CAUqLggCIhB3D3-fe0rLUkFbhliShCPgKhgIBCoPCAAqBwgKMI7oyQEw18wVMIiUtAEwyuzNzylqCmltYWdlL2pwZWc","http://s.marketwatch.com/public/resources/images/MW-GC385_tidede_ZH_20180124145416.jpg"]
# ]
# ,null,[6,[6,"CAAqBwgKMI7oyQEw18wV"]
# ,"MarketWatch",["https://lh3.googleusercontent.com/IP0rIUyaxJGzqJVAgpUQG6EW0pfVGWHI7tsTrJmuv_5FJnDFjW_4IhVAqkdvxvPna9OibR0dDd72oa19pcA"]
# ]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to MarketWatch","publications/CAAqBwgKMI7oyQEw18wV",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"http://www.marketwatch.com/story/the-dangerous-teenage-tide-pod-challenge-may-actually-boost-their-sales-2018-01-24",1,"https://www-marketwatch-com.cdn.ampproject.org/v/s/www.marketwatch.com/amp/story/guid/3B8CD08C-0140-11E8-A71A-B69E3BC69E97?amp_js_v\u003d0.1#webview\u003d1",null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEHcPf597SstSQVuGWJKEI-AqGAgEKg8IACoHCAowjujJATDXzBUwiJS0AQ"]
# ,[3,null,null,[2,[2,"CAIiEOFtnAdOj8xWQzYuUKi7VSoqFQgEKg0IACoGCAowkpEDMOJQMKGiAg"]
# ,"Brand Crisis Management: Responding to the Tide Pod Challenge","When Tide and other detergent manufacturers developed colorful, convenient pods designed to be tossed into washing machines and dishwashers, they never expected teenagers would try to eat them. But what was dubbed the Tide pod challenge quickly went viral, with teens posting videos of themselves spewing soap across social media channels. The American Association of Poison Control Centers last year reported 220 teens were exposed to the toxic pods, and about 40 cases have been reported so far this year. The dangerous debacle has created a different kind of challenge for Procter \u0026 Gamble, whi...",[1516920331]
# ,null,"http://knowledge.wharton.upenn.edu/article/fallout-tide-pod-challenge/","https://news.google.com/s/CBIwxo65xjc?oc\u003d3",[["https://lh3.googleusercontent.com/XVNXpWDEagzg7GRZFRGQ9nm3JiJP4qwCMy9SZa2lCkJtI7TRTvWFyJd4rmCqv-Tl0eW3v14_yeCst6rAgg","",1024,440,"","CAUqKwgCIhDhbZwHTo_MVkM2LlCou1UqKhUIBCoNCAAqBggKMJKRAzDiUDChogIwr6iIjCpqCmltYWdlL2pwZWc","http://knowledge.wharton.upenn.edu/wp-content/uploads/2018/01/012518_tidepods.jpg"]
# ]
# ,null,[6,[6,"CAAqBggKMJKRAzDiUA"]
# ,"Knowledge@Wharton",["https://lh3.googleusercontent.com/eesyK41xrao0r4gTCJlgFa21qVQbT5r4UWRoH59Mnt_mbWqi40MYQqUKDyUspXpYVaM8p8cBV42h4sTeYc75"]
# ]
# ,null,null,"Knowledge@Wharton",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to Knowledge@Wharton","publications/CAAqBggKMJKRAzDiUA",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"http://knowledge.wharton.upenn.edu/article/fallout-tide-pod-challenge/",1,null,null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEOFtnAdOj8xWQzYuUKi7VSoqFQgEKg0IACoGCAowkpEDMOJQMKGiAg"]
# ,[3,null,null,[2,[2,"CAIiEBb84-5XQIGoiMmpMBJWylcqFwgEKg8IACoHCAowhO7OATDh9Cgwm4pR"]
# ,"CEO says company working to stop 'Tide pod challenge'","NEW YORK (AP) — Procter \u0026 Gamble says it's working to stop the \"Tide Pod challenge,\" a social media-fueled trend in which teenagers eat single-load laundry detergent packets. The American Association of Poison Control Centers warned last week that it had seen a spike in teenagers eating the detergent pods, which it says can cause seizures, respiratory arrest and even death. CEO David Taylor called the trend \"dangerous\" and \"extremely concerning\" in an online post Monday. He said the company is working with social media companies to remove videos of people biting into the detergent, and aske...",[1516738633]
# ,null,"http://www.apnewsarchive.com/2018/P-G-says-it-s-working-to-stop-the-Tide-Pod-challenge-calls-trend-dangerous/id-804c363c292245e3950ec61fbfe7adb1","https://news.google.com/s/CBIw_6u0rjo?oc\u003d3",[["https://lh3.googleusercontent.com/lLudf9_MmqMpSgzf8BceNpDmn7ZYnEIdRUjJRJTBotnCA_X313-lQHDLOXs58y58WrLVdshh8hCYe49qHMGQ","FILE - In this Tuesday, Oct. 10, 2017, file photo, Procter \u0026 Gamble CEO David Taylor answers questions at a news conference following P\u0026G's shareholder vote, in Cincinnati. P\u0026G says it’s working to stop the “Tide Pod challenge,” a social media-fueled trend in which teenagers eat single-load laundry detergent packets. Taylor called the trend “dangerous” and “extremely concerning” in a blog post Monday, Jan. 23, 2018. (Kareem Elgazzar/The Cincinnati Enquirer via AP, File)",3848,2756,"","CAUqLQgCIhAW_OPuV0CBqIjJqTASVspXKhcIBCoPCAAqBwgKMITuzgEw4fQoMJuKUTDP6OyLKmoKaW1hZ2UvanBlZw","http://syndication.ap.org/AP.Distro.ContentBroker2/ContentBroker.aspx?contentid\u003db602aebd037f4d60ad8631330e7fdaeb\u0026iid\u003d1febd3c3e58f442f91a41a3474b2c8b6\u0026rsn\u003d0\u0026recordid\u003d1febd3c3e58f442f91a41a3474b2c8b6\u0026filingId\u003dd946dd34a22043fd99b95ee256d792b8\u0026role\u003dMain\u0026reldt\u003d2018-01-23T17:14:43\u0026media\u003dPhoto\u0026sz\u003d2733120\u0026dest\u003dak\u0026trF\u003dOHCIN301\u0026ofn\u003dTide_Pod_Challenge-CEO_Warning_75042.jpg\u0026fmt\u003djpg\u0026relativeUrl\u003djpg/2018/201801/23/b602aebd037f4d60ad8631330e7fdaeb.jpg\u0026s3Key\u003deNorSy0qzszPK9YvTk0uLUpN0c9NzMzTLTMw0MsqSAcAq80K2g%3d%3d\u0026entid\u003d42428\u0026authToken\u003deNolzEsKwzAMANHLdGtQ%2fJHlhaBH6A1KXMnBUHAgBGehwzfQ9QzP9GIMmHwqEYkAgApG%2b3SuCH7VKg5Cbi4KgluF0IUlBNDc5I42ujCWFMjOg7cxtq8mfE%2btTVUOOzvfSilk%2b%2bTna7bHf%2b47Ow%2fZLz7iQj%2fsEibS"]
# ]
# ,null,[6,[6,"CAAqBwgKMITuzgEw4fQo"]
# ,"The Associated Press",["https://lh3.googleusercontent.com/-I4wu4ggbhbYTZv6lj7N_aD_KOfnoKuyWtPbA2qbEciordMrQlbOlcX5k0iymOWN6zZ1JeBntJm2JeURag"]
# ]
# ,null,null,"-",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to The Associated Press","publications/CAAqBwgKMITuzgEw4fQo",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"http://www.apnewsarchive.com/2018/P-G-says-it-s-working-to-stop-the-Tide-Pod-challenge-calls-trend-dangerous/id-804c363c292245e3950ec61fbfe7adb1",1,null,null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEBb84-5XQIGoiMmpMBJWylcqFwgEKg8IACoHCAowhO7OATDh9Cgwm4pR"]
# ,[3,null,null,[2,[2,"CAIiEEDG_7DmtCr89jNS4FOG8LwqFQgEKg0IACoGCAowlIECMLBMMJ-mHg"]
# ,"Maker of Tide Pods: It's Not Our Fault That Teens Are Fucking Stupid","Photo: AP Why are teens eating Tide pods? Or, at least, pretending to eat them in videos that they’re posting online? We have some theories. But the company that makes the brightly colored laundry pods would like you to know that, whatever the reason, it’s not their fault. Procter \u0026 Gamble, the company that manufacturers Tide pods, is clearly in a tough spot. Kids are eating their poisonous laundry detergent as a kind of nihilistic joke (drinking bleach was all the rage this past summer) and while the old saying is that there’s no such thing as bad publicity, this is pretty bad. The CEO of ...",[1516710900]
# ,null,"https://gizmodo.com/maker-of-tide-pods-its-not-our-fault-that-teens-are-fu-1822325352","https://news.google.com/s/CBIws9qCwjc?oc\u003d3",[["https://lh3.googleusercontent.com/P40UETCz7Vy7bdSfNEM94WfTH5EH2LgIrVzVSzDMjxxfmjlnhNNfYRAZ7ZwLAG4-1kas3zLObQw-CbyVc2E","Maker of Tide Pods: It's Not Our Fault That Teens Are Fucking Stupid",800,450,"","CAUqKwgCIhBAxv-w5rQq_PYzUuBThvC8KhUIBCoNCAAqBggKMJSBAjCwTDCfph4wn6igmCpqCmltYWdlL2pwZWc","https://i.kinja-img.com/gawker-media/image/upload/s--wNQd8HBR--/c_fill,fl_progressive,g_center,h_450,q_80,w_800/nw5apxpiyaznrujms4gh.jpg"]
# ]
# ,null,[6,[6,"CAAqBggKMJSBAjCwTA"]
# ,"Gizmodo",["https://lh3.googleusercontent.com/jrX7A0iaVBDYgciIAOS3wyt5AhP43YkuGJVIijgByM4eFeEmWYT2aFzs1QN47GmkkchymlKy3egJsv4dEg"]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,["https://lh3.googleusercontent.com/rOvhCAnWxXSuPz95lksSmQ67FgUzF0Z9dM4wfdH1-KziY5N_qgQt1EoMhTATeulbUIMs1RQU-A",null,4543,650,null,"CAUqBggKMJSBAjDOg7WKKmoJaW1hZ2UvcG5n"]
# ]
# ,null,null,"Matt Novak",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to Gizmodo","publications/CAAqBggKMJSBAjCwTA",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"https://gizmodo.com/maker-of-tide-pods-its-not-our-fault-that-teens-are-fu-1822325352",1,null,null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEEDG_7DmtCr89jNS4FOG8LwqFQgEKg0IACoGCAowlIECMLBMMJ-mHg"]
# ,[3,null,null,[2,[2,"CAIiEE4YsbwpydAposZDgQ43lI8qFQgEKg0IACoGCAowrqkBMKBFMI_CEg"]
# ,"P\u0026G's Gillette Woes Have Translated To This Good News For Consumers","Gillette’s price cut has looked to help send industrywide average shaving product price to its lowest in at least five years. (Photo by Darren Durlach/The Boston Globe via Getty Images) The price you pay for razors and other shaving products has gone down, and you can thank Gillette parent Procter \u0026 Gamble partly for that. Average industrywide US unit price of shaving products declined 4.5% last year to $6.14, the lowest price in at least five years, according to Nielsen data, which tracks actual sales of UPC-coded consumer packaged goods at retailers from supermarkets and drug stores to ma...",[1516806000]
# ,null,"https://www.forbes.com/sites/andriacheng/2018/01/24/pgs-gillette-woes-have-translated-to-this-good-news-for-consumers/","https://news.google.com/s/CBIwiKbJrjo?oc\u003d3",[["https://lh3.googleusercontent.com/9injIv2p4X1dG8u3ki1vOF2kIk4ohb826K3Wuf68A-ZWKbW0S4wC0L0wm6TGiouhads3uE6v2sEhUC8wJQ","",960,643,"","CAUqKwgCIhBOGLG8KcnQKaLGQ4EON5SPKhUIBCoNCAAqBggKMK6pATCgRTCPwhIwk__0iypqCmltYWdlL2pwZWc","https://specials-images.forbesimg.com/dam/imageserve/450559914/960x0.jpg?fit\u003dscale"]
# ]
# ,null,[6,[6,"CAAqBggKMK6pATCgRQ"]
# ,"Forbes Now",["https://lh3.googleusercontent.com/aNI3iLAxdSHXkxORl-PDsaDRmzGuWf4ZFKqw7pTCoAdF-FaGQ4cxV_EHBeH14ObqULfJwbyQlGNXRVHTWA"]
# ]
# ,null,null,"Andria Cheng, Contributor",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to Forbes Now","publications/CAAqBggKMK6pATCgRQ",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"https://www.forbes.com/sites/andriacheng/2018/01/24/pgs-gillette-woes-have-translated-to-this-good-news-for-consumers/",1,"https://www-forbes-com.cdn.ampproject.org/v/s/www.forbes.com/sites/andriacheng/2018/01/24/pgs-gillette-woes-have-translated-to-this-good-news-for-consumers/amp/?amp_js_v\u003d0.1#webview\u003d1",null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEE4YsbwpydAposZDgQ43lI8qFQgEKg0IACoGCAowrqkBMKBFMI_CEg"]
# ,[3,null,null,[2,[2,"CAIiEBzUugJrR_vixwDE355tVPUqEwgEKgwIACoFCAowgHkwoBEwwjU"]
# ,"3 Big-Brand Stocks to Buy Now","What's in a name? Well, for many companies a name can be everything. Some brand names are so beloved that consumers will gravitate toward a brand's products practically without thinking of the alternatives. That's a serious competitive advantage for a company, and one that can be worth billions of dollars. Investors looking to capitalize on the competitive advantages afforded by a big brand would do well to look into these three stocks. Image source: Disney. The most magical place on Earth Walt Disney (NYSE: DIS) is a media conglomerate that houses several popular brands. There's its flagsh...",[1517439780]
# ,null,"https://www.fool.com/investing/2018/01/31/3-big-brand-stocks-to-buy-now.aspx","https://news.google.com/s/CBIwjcWZsTo?oc\u003d3",[["https://lh3.googleusercontent.com/dCV46a5_tctMrtKCfXf4zdIiXYVL09A0Sq4nhun2FOs2Rh40RfGD3DEBGNb_WpyWI14D5Kos_34ZJBgivKND","",580,387,"","CAUqKQgCIhAc1LoCa0f74scAxN-ebVT1KhMIBCoMCAAqBQgKMIB5MKARMMI1MP34w4wqagppbWFnZS9qcGVn","https://g.foolcdn.com/editorial/images/470759/starbucks_holiday_cup_2017_1_large.JPG"]
# ]
# ,null,[6,[6,"CAAqBQgKMIB5MKAR"]
# ,"The Motley Fool",["https://lh3.googleusercontent.com/6BeyGQnJbhlKj1udLYOFvdXDZMXzLJc__SWXuEapiZ5buUrvweioya_wOI3R9kyBWCVSKh-bYOK1aKs7DYI"]
# ]
# ,null,null,"newsfeedback@fool.com (Adam Levy)",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"4 months ago",null,[null,[["Go to The Motley Fool","publications/CAAqBQgKMIB5MKAR",[null,null,null,null,null,"link"]
# ,0]
# ]
# ]
# ,true,"https://www.fool.com/investing/2018/01/31/3-big-brand-stocks-to-buy-now.aspx",1,"https://www-fool-com.cdn.ampproject.org/v/s/www.fool.com/amp/investing/2018/01/31/3-big-brand-stocks-to-buy-now.aspx?amp_js_v\u003d0.1#webview\u003d1",null,[[18,null,null,null,"",null,141,null,null,null,47]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CAIiEBzUugJrR_vixwDE355tVPUqEwgEKgwIACoFCAowgHkwoBEwwjU"]
# ]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"topics/CAAqJggKIiBDQkFTRWdvSkwyMHZNREZ4ZVdkc0VnVmxiaTFWVXlnQVAB/sections/CAQqKggAKiYICiIgQ0JBU0Vnb0pMMjB2TURGeGVXZHNFZ1ZsYmkxVlV5Z0FQAQ",null,[null,null,null,[null,null,null,null,null,null,null,[null,null,"Latest"]
# ]
# ]
# ,null,null,2]
# ,null,null,null,null,null,"aa|CAQqKggAKiYICiIgQ0JBU0Vnb0pMMjB2TURGeGVXZHNFZ1ZsYmkxVlV5Z0FQAQ"]
# ]
# }});</script><script aria-hidden="true" nonce="7puXDYhKeo0dl4Er1YRBsmDVeZo">window.wiz_progress&&window.wiz_progress(); ccTick('bl');</script></div></body></html>

# %%
nameList = bsobj.findAll('span')
print(nameList)
# Out:
# [<span class="gb_1a gb_Ic"></span>, <span class="gb_ne gb_ie">News</span>, <span class="gb_Zc"></span>, <span class="gb_2" style="background-position:0 -69px"></span>, <span class="gb_3">My Account</span>, <span class="gb_2" style="background-position:0 -1656px"></span>, <span class="gb_3">Search</span>, <span class="gb_2" style="background-position:0 -897px"></span>, <span class="gb_3">Maps</span>, <span class="gb_2" style="background-position:0 -1311px"></span>, <span class="gb_3">YouTube</span>, <span class="gb_2" style="background-position:0 -1518px"></span>, <span class="gb_3">Play</span>, <span class="gb_2" style="background-position:0 -207px"></span>, <span class="gb_3">News</span>, <span class="gb_2" style="background-position:0 -345px"></span>, <span class="gb_3">Gmail</span>, <span class="gb_2" style="background-position:0 -966px"></span>, <span class="gb_3">Contacts</span>, <span class="gb_2" style="background-position:0 -1449px"></span>, <span class="gb_3">Drive</span>, <span class="gb_2" style="background-position:0 -1242px"></span>, <span class="gb_3">Calendar</span>, <span class="gb_2" style="background-position:0 -690px"></span>, <span class="gb_3">Translate</span>, <span class="gb_2" style="background-position:0 -414px"></span>, <span class="gb_3">Photos</span>, <span class="gb_ka"></span>, <span class="gb_2" style="background-position:0 -2208px"></span>, <span class="gb_3">Shopping</span>, <span class="gb_2" style="background-position:0 -1863px"></span>, <span class="gb_3">Finance</span>, <span class="gb_2" style="background-position:0 -1380px"></span>, <span class="gb_3">Docs</span>, <span class="gb_2" style="background-position:0 -2070px"></span>, <span class="gb_3">Books</span>, <span class="gb_2" style="background-position:0 -759px"></span>, <span class="gb_3">Blogger</span>, <span class="gb_2" style="background-position:0 -1794px"></span>, <span class="gb_3">Hangouts</span>, <span class="gb_M"></span>, <span class="gb_3">Keep</span>, <span class="gb_1a gb_Ic"></span>, <span class="gb_ne gb_ie">News</span>, <span aria-hidden="true" class="DPvwYc hGhvff">play_newsstand</span>, <span aria-hidden="true" class="ICsaqd">Top stories</span>, <span aria-label="For you" class="SFllF" jsaction="click:yQ77L;" tabindex="0"><div class="PysvYb"><span aria-hidden="true" class="DPvwYc hGhvff">person</span></div><div class="e20EGc"><span aria-hidden="true" class="ICsaqd">For you</span></div></span>, <span aria-hidden="true" class="DPvwYc hGhvff">person</span>, <span aria-hidden="true" class="ICsaqd">For you</span>, <span aria-label="Favorites" class="SFllF" jsaction="click:yQ77L;" tabindex="0"><div class="PysvYb"><span aria-hidden="true" class="DPvwYc hGhvff">star_border</span></div><div class="e20EGc"><span aria-hidden="true" class="ICsaqd">Favorites</span></div></span>, <span aria-hidden="true" class="DPvwYc hGhvff">star_border</span>, <span aria-hidden="true" class="ICsaqd">Favorites</span>, <span aria-label="Saved searches" class="SFllF" jsaction="click:yQ77L;" tabindex="0"><div class="PysvYb"><span aria-hidden="true" class="DPvwYc hGhvff">search</span></div><div class="e20EGc"><span aria-hidden="true" class="ICsaqd">Saved searches</span></div></span>, <span aria-hidden="true" class="DPvwYc hGhvff">search</span>, <span aria-hidden="true" class="ICsaqd">Saved searches</span>, <span aria-hidden="true" class="DPvwYc hGhvff">flag</span>, <span aria-hidden="true" class="ICsaqd">U.S.</span>, <span aria-hidden="true" class="DPvwYc hGhvff">public</span>, <span aria-hidden="true" class="ICsaqd">World</span>, <span aria-hidden="true" class="DPvwYc hGhvff">room</span>, <span aria-hidden="true" class="ICsaqd">Local</span>, <span aria-hidden="true" class="DPvwYc hGhvff">business</span>, <span aria-hidden="true" class="ICsaqd">Business</span>, <span aria-hidden="true" class="DPvwYc hGhvff">memory</span>, <span aria-hidden="true" class="ICsaqd">Technology</span>, <span aria-hidden="true" class="DPvwYc hGhvff">theaters</span>, <span  ...
